# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import os
import sys

# 添加项目根目录到路径
# sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath(__file__))))

from postgres_manager import PostgreSQLManager
from advanced_manager import AdvancedPostgreSQLManager

# %%
db = PostgreSQLManager()
# Out:
# 2025-09-23 13:43:21 | INFO | 数据库连接成功

# %%
hfq_close = pd.read_csv("D:/program_learning/光大实习/raw_data/hfq/close.csv",index_col='date')

# %%
c = hfq_close.iloc[:,:500]

# %%
c
# Out:
#              600000.SH  600004.SH  600006.SH  600007.SH  600008.SH  600009.SH  \
# date
# 2015-01-05   96.671576  16.021395  16.326623  20.396198  32.716495  49.796891
# 2015-01-06   97.032515  16.076404  16.588268  19.671460  35.990851  48.729641
# 2015-01-07   95.107506  15.911376  16.248130  19.658518  34.529568  48.947942
# 2015-01-08   91.738739  15.567570  15.724840  19.179673  34.231899  48.511340
# 2015-01-09   92.821557  15.636331  15.515525  18.985547  33.095346  48.390062
# ...                ...        ...        ...        ...        ...        ...
# 2025-03-25  131.439969  20.351252  20.425460  38.766155  23.375872  85.740809
# 2025-03-26  129.705606  20.262576  20.851582  38.715590  23.155344  85.297232
# 2025-03-27  130.696671  20.240407  20.567501  38.479623  23.008326  85.323325
# 2025-03-28  129.333956  20.173899  21.107255  38.766155  23.008326  84.801470
# 2025-03-31  129.210073  20.040884  21.902684  38.766155  22.934817  84.357893
#
# ...

# %%
success = db.create_table("equity_fundamental_data.price_hfq_close",
                        c,overwrite=True)
# Out:
# 2025-09-23 13:57:12 | INFO | [Function: create_table started...]
# 2025-09-23 13:57:12 | INFO | 直接使用传入的DataFrame，形状: (2488, 500)
# 2025-09-23 13:57:12 | ERROR | 创建表 equity_fundamental_data.price_hfq_close 失败: 错误:  关系 "price_hfq_close" 已经存在
#
# 2025-09-23 13:57:12 | ERROR | 详细错误信息: Traceback (most recent call last):
#   File "d:\program_learning\factor_frame\Datadeal\postgres_manager.py", line 190, in create_table
#     self._create_table_from_dataframe(table_name, df)
#   File "d:\program_learning\factor_frame\Datadeal\postgres_manager.py", line 311, in _create_table_from_dataframe
#     self.cursor.execute(create_sql)
#   File "d:\ANACONDA\lib\site-packages\psycopg2\extras.py", line 236, in execute
#     return super().execute(query, vars)
# psycopg2.errors.DuplicateTable: 错误:  关系 "price_hfq_close" 已经存在
#
#
# 2025-09-23 13:57:12 | INFO | [Function: create_table completed, elapsed time: 0.02s]

# %%
'aaa.bbb'.split('.')[-1]
# Out:
# 'bbb'

# %%
df = db.query_data("equity_fundamental_data.price_hfq_close", start_date='2016-01-01', end_date='2019-02-01')
# Out:
# 2025-09-23 13:30:15 | INFO | [Function: query_data started...]
# 2025-09-23 13:30:15 | INFO | 执行查询: SELECT * FROM equity_fundamental_data.price_hfq_close WHERE datetime >= %s AND datetime <= %s ORDER BY datetime
# 2025-09-23 13:30:15 | INFO | 查询完成，返回数据形状: (754, 500)
# 2025-09-23 13:30:15 | INFO | [Function: query_data completed, elapsed time: 0.57s]

# %%
df
# Out:
#              600000.SH  600004.SH  600006.SH  600007.SH  600008.SH  \
# datetime
# 2016-01-04  112.068213  18.196811  20.919666  22.599994  25.149792
# 2016-01-05  113.075567  18.336358  20.159427  22.089924  25.286475
# 2016-01-06  113.957003  18.741041  20.657515  22.299184  25.696526
# 2016-01-07  110.242382  17.331626  18.612735  20.075805  23.154210
# 2016-01-08  110.116463  17.722355  18.691381  20.088883  24.247680
# ...                ...        ...        ...        ...        ...
# 2019-01-28   98.832054  23.950289  10.164870  18.289706  19.560245
# 2019-01-29  100.349628  23.671048   9.844717  18.070175  19.274277
# 2019-01-30   99.590841  24.293970   9.657961  18.097616  19.159889
# 2019-01-31  101.772355  25.367974   9.684640  18.221103  18.988308
# 2019-02-01  102.151748  24.916893   9.844717  18.138779  19.388664
#
#              600009.SH  600010.SH  600011.SH  600012.SH  600015.SH  ...  \
# datetime                                                            ...
# ...
